# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
URL_DATA = 'https://storage.dosm.gov.my/hies/hh_inequality_state.parquet'

df = pd.read_parquet(URL_DATA)
if 'date' in df.columns: df['date'] = pd.to_datetime(df['date'])

print(df)
# Out:
#               state       date   gini
# 0             Johor 1974-01-01  0.439
# 1             Johor 1976-01-01  0.469
# 2             Johor 1979-01-01  0.442
# 3             Johor 1984-01-01  0.404
# 4             Johor 1987-01-01  0.386
# ..              ...        ...    ...
# 268  W.P. Putrajaya 2012-01-01  0.305
# 269  W.P. Putrajaya 2014-01-01  0.374
# 270  W.P. Putrajaya 2016-01-01  0.369
# 271  W.P. Putrajaya 2019-01-01  0.361
# 272  W.P. Putrajaya 2022-01-01  0.368
#
# [273 rows x 3 columns]

# %%
#Change to dt.
df['year'] = df['date'].dt.year
df
# Out:
#               state       date   gini  year
# 0             Johor 1974-01-01  0.439  1974
# 1             Johor 1976-01-01  0.469  1976
# 2             Johor 1979-01-01  0.442  1979
# 3             Johor 1984-01-01  0.404  1984
# 4             Johor 1987-01-01  0.386  1987
# ..              ...        ...    ...   ...
# 268  W.P. Putrajaya 2012-01-01  0.305  2012
# 269  W.P. Putrajaya 2014-01-01  0.374  2014
# 270  W.P. Putrajaya 2016-01-01  0.369  2016
# 271  W.P. Putrajaya 2019-01-01  0.361  2019
# 272  W.P. Putrajaya 2022-01-01  0.368  2022
#
# [273 rows x 4 columns]

# %%
df['state'].value_counts()
# Out:
# state
# Johor                19
# Kedah                19
# Kelantan             19
# Melaka               19
# Negeri Sembilan      19
# Pahang               19
# Perak                19
# Perlis               19
# Pulau Pinang         19
# Selangor             19
# Terengganu           19
# Sabah                17
# Sarawak              17
# W.P. Kuala Lumpur    16
# W.P. Labuan           7
# W.P. Putrajaya        7
# Name: count, dtype: int64

# %%
year_1 = 1984
year_2 = 2022

df1 = df[df['year'] == year_1].sort_values('gini',ascending=False)
df2 = df[df['year'] == year_2].sort_values('gini',ascending=False)
df1
# Out:
#                  state       date   gini  year
# 189            Sarawak 1984-01-01  0.498  1984
# 172              Sabah 1984-01-01  0.491  1984
# 243  W.P. Kuala Lumpur 1984-01-01  0.486  1984
# 208           Selangor 1984-01-01  0.481  1984
# 22               Kedah 1984-01-01  0.476  1984
# 41            Kelantan 1984-01-01  0.464  1984
# 227         Terengganu 1984-01-01  0.461  1984
# 136             Perlis 1984-01-01  0.459  1984
# 155       Pulau Pinang 1984-01-01  0.452  1984
# 60              Melaka 1984-01-01  0.438  1984
# 117              Perak 1984-01-01  0.428  1984
# 79     Negeri Sembilan 1984-01-01  0.422  1984
# 98              Pahang 1984-01-01  0.416  1984
# 3                Johor 1984-01-01  0.404  1984

# %%
fig, axes = plt.subplots(1,2,figsize=(22,8))

fig.suptitle(f'Gini coefficient by states {year_1} vs {year_2}')

sns.barplot(ax=axes[0], data = df1, x='gini',y='state', color='cyan')
sns.barplot(ax=axes[1], data = df2, x='gini',y='state', color='cyan')
# Out:
# <Axes: xlabel='gini', ylabel='state'>
